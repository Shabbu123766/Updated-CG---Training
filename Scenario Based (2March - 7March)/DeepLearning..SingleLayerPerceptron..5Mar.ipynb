# %%
# Scenario:
# We want to classify whether a restaurant order is “Large” (1) or “Small” (0) based on the number
#  of items ordered.
# - If items ≥ 3 → Large order
# - If items < 3 → Small order

import numpy as np

# Step 1: Training Data
# X = number of items ordered
# y = order type (0 = Small, 1 = Large)

X = np.array([[1], [2], [3], [4]])
y = np.array([0, 0, 1, 1])

# Step 2: Initialize weights and bias
weights = np.random.rand(1)
bias = np.random.rand(1)

learning_rate = 0.1

# Step 3: Activation Function
def activation(z):
    return 1 if z >= 0 else 0

# Step 4: Training Loop
for epoch in range(10):
    print(f"Epoch {epoch+1}")

    for i in range(len(X)):

        # Linear combination
        z = np.dot(X[i], weights) + bias
        y_pred = activation(z)

        # Error
        error = y[i] - y_pred

        # Update rule
        weights += learning_rate * error * X[i]
        bias += learning_rate * error

        print(f"Input: {X[i]}, Predicted: {y_pred}, Actual: {y[i]}, Error: {error}")


print("\nFinal Weights:", weights)
print("Final Bias:", bias)

# Test the perceptron
test_orders = [2, 3, 5]

for order in test_orders:
    z = np.dot([order], weights) + bias

    print(f"Items Ordered: {order}, Prediction:", "Large" if prediction==1 else "Small")
# Out:
# Epoch 1
# Input: [1], Predicted: 1, Actual: 0, Error: -1
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 1, Actual: 1, Error: 0
# Input: [4], Predicted: 1, Actual: 1, Error: 0
# Epoch 2
# Input: [1], Predicted: 1, Actual: 0, Error: -1
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [4], Predicted: 1, Actual: 1, Error: 0
# Epoch 3
# Input: [1], Predicted: 1, Actual: 0, Error: -1
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [4], Predicted: 1, Actual: 1, Error: 0
# Epoch 4
# Input: [1], Predicted: 1, Actual: 0, Error: -1
# Input: [2], Predicted: 0, Actual: 0, Error: 0
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [4], Predicted: 1, Actual: 1, Error: 0
# Epoch 5
# Input: [1], Predicted: 1, Actual: 0, Error: -1
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [4], Predicted: 1, Actual: 1, Error: 0
# Epoch 6
# Input: [1], Predicted: 1, Actual: 0, Error: -1
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [4], Predicted: 1, Actual: 1, Error: 0
# Epoch 7
# Input: [1], Predicted: 1, Actual: 0, Error: -1
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [4], Predicted: 1, Actual: 1, Error: 0
# Epoch 8
# Input: [1], Predicted: 0, Actual: 0, Error: 0
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [4], Predicted: 1, Actual: 1, Error: 0
# Epoch 9
# Input: [1], Predicted: 1, Actual: 0, Error: -1
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 0, Actual: 1, Error: 1
# Input: [4], Predicted: 1, Actual: 1, Error: 0
# Epoch 10
# Input: [1], Predicted: 0, Actual: 0, Error: 0
# Input: [2], Predicted: 1, Actual: 0, Error: -1
# Input: [3], Predicted: 1, Actual: 1, Error: 0
# Input: [4], Predicted: 1, Actual: 1, Error: 0
#
# Final Weights: [0.25887341]
# Final Bias: [-0.58627149]
# Items Ordered: 2, Prediction: Large
# Items Ordered: 3, Prediction: Large
# Items Ordered: 5, Prediction: Large
